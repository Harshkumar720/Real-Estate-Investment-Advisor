# %%
import pandas as pd

raw = pd.read_csv("../data/raw/india_housing_prices.csv")
clean = pd.read_csv("../data/processed/cleaned_data.csv")

print(raw.shape, clean.shape)
# Out:
# (250000, 23) (250000, 24)

# %%
print(raw.columns)
print(clean.columns)
# Out:
# Index(['ID', 'State', 'City', 'Locality', 'Property_Type', 'BHK',
#        'Size_in_SqFt', 'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built',
#        'Furnished_Status', 'Floor_No', 'Total_Floors', 'Age_of_Property',
#        'Nearby_Schools', 'Nearby_Hospitals', 'Public_Transport_Accessibility',
#        'Parking_Space', 'Security', 'Amenities', 'Facing', 'Owner_Type',
#        'Availability_Status'],
#       dtype='object')
# Index(['ID', 'State', 'City', 'Locality', 'Property_Type', 'BHK',
#        'Size_in_SqFt', 'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built',
#        'Furnished_Status', 'Floor_No', 'Total_Floors', 'Age_of_Property',
#        'Nearby_Schools', 'Nearby_Hospitals', 'Public_Transport_Accessibility',
#        'Parking_Space', 'Security', 'Amenities', 'Facing', 'Owner_Type',
#        'Availability_Status', 'Property_Age'],
#       dtype='object')

# %%
clean["City"] = raw["City"]
clean["Property_Type"] = raw["Property_Type"]
clean["Furnished_Status"] = raw["Furnished_Status"]

# %%
clean[["City", "Property_Type", "Furnished_Status"]].head()
# Out:
#        City      Property_Type Furnished_Status
# 0   Chennai          Apartment        Furnished
# 1      Pune  Independent House      Unfurnished
# 2  Ludhiana          Apartment   Semi-furnished
# 3   Jodhpur  Independent House        Furnished
# 4    Jaipur              Villa   Semi-furnished

# %%
clean.to_csv("../data/processed/cleaned_data.csv", index=False)
